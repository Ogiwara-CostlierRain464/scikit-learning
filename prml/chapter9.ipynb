# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from prml.clustering.k_means import KMeans
from prml.rv.multivariate_gaussian_mixture import MultivariateGaussianMixture

# %%
# training data
x1 = np.random.normal(size=(100, 2))
x1 += np.array([-5, -5])
x2 = np.random.normal(size=(100, 2))
x2 += np.array([5, -5])
x3 = np.random.normal(size=(100, 2))
x3 += np.array([0, 5])
x_train = np.vstack((x1, x2, x3))

x0, x1 = np.meshgrid(np.linspace(-10, 10, 100), np.linspace(-10, 10, 100))
x = np.array([x0, x1]).reshape(2, -1).T# training data

k_means = KMeans(n_clusters=3)
k_means.fit(x_train)
cluster = k_means.predict(x_train)

plt.scatter(x_train[:, 0], x_train[:, 1], c=cluster)
plt.scatter(k_means.centers[:, 0], k_means.centers[:, 1], s=200, marker="X", lw=2, c=["purple", "cyan", "yellow"], edgecolors="white")
plt.contourf(x0, x1, k_means.predict(x).reshape(100, 100), alpha=0.1)
plt.show()

gmm = MultivariateGaussianMixture(n_components=2)
gmm.fit(x_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ee6b63b44404> in <module>
#      21
#      22 gmm = MultivariateGaussianMixture(n_components=2)
# ---> 23 gmm.fit(x_train)
#
# ~/Desktop/scikit-play/prml/rv/multivariate_gaussian_mixture.py in fit(self, X)
#      19         self.pi = np.ones(self.n_components) / self.n_components
#      20         for _ in range(1000):
# ---> 21             status = self.expectation(X)
#      22             self.maximization(X, status)
#      23
#
# ~/Desktop/scikit-play/prml/rv/multivariate_gaussian_mixture.py in expectation(self, X)
#      23
#      24     def expectation(self, X: np.ndarray):
# ---> 25         resps = self.pi * self._gauss(X)
#      26         resps /= resps.sum(axis=-1, keepdims=True)
#      27         return resps
#
# ~/Desktop/scikit-play/prml/rv/multivariate_gaussian_mixture.py in _gauss(self, X)
#      39         D_sq = np.sum(np.einsum('nki,kij->nkj', d, self.cov) * d, -1)
#      40         return (
# ---> 41             np.exp(-0.5 * D_sq) / np.sqrt(np.linalg.det(self.cov) * (2 * np.pi) ** self.ndim)
#      42         )
#      43
#
# AttributeError: 'MultivariateGaussianMixture' object has no attribute 'ndim'
